# %% [markdown]
# # 03 — Torneo de Modelos
#
# ## Objetivo
# Comparar baselines y modelos ML sobre **validation** (NUNCA test). Generar scorecard completo y visualización de backtesting.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import json, joblib
from pathlib import Path
from datetime import datetime
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import ElasticNet
import plotly.express as px
import plotly.graph_objects as go

# Prophet opcional
try:
    from prophet import Prophet
    HAS_PROPHET = True
    print("✅ Prophet disponible")
except ImportError:
    HAS_PROPHET = False
    print("⚠️ Prophet no instalado — se omite del torneo")

# %% [markdown]
# ## 1. Carga de datos

# %%
# TODO: cargar train.csv, validation.csv, feature_list.json

# %% [markdown]
# ## 2. Funciones de métricas
#
# Scorecard completo: MAPE, SMAPE, MdAPE, MAE, RMSE, MdAE, POE, PUE, MOE, MUE

# %%
# TODO: implementar funciones de métricas

# %% [markdown]
# ## 3. Baselines (lag-1, lag-7, MA-7)

# %%
# TODO: evaluar baselines

# %% [markdown]
# ## 4. ElasticNet

# %%
# TODO: entrenar y evaluar

# %% [markdown]
# ## 5. GradientBoosting (central + cuantil 95)

# %%
# TODO: entrenar y evaluar

# %% [markdown]
# ## 6. Prophet (opcional)

# %%
# TODO: entrenar si HAS_PROPHET

# %% [markdown]
# ## 7. Scorecard comparativo (tabla)

# %%
# TODO: generar tabla con MAPE, SMAPE, MdAPE, MAE, RMSE, POE, PUE, MOE, MUE

# %% [markdown]
# ## 8. Gráfico de backtesting (real vs predicho)

# %%
# TODO: serie temporal validation - real vs predicción de cada modelo

# %% [markdown]
# ## 9. Leaderboard visual (MAPE)

# %%
# TODO: bar chart de MAPE por modelo

# %% [markdown]
# ## 10. Persistencia de modelos

# %%
# TODO: guardar modelos, metadata, leaderboard

# %% [markdown]
# ## 11. Conclusiones
#
# **Estado:** GO / REVISAR / NO-GO
#
# **Mejor modelo (validación):**
#
# **Siguiente:** evaluation-business

# %%
# TODO: generar manifest
