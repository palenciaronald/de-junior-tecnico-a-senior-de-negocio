# %% [markdown]
# # 03 — Torneo de Modelos

# %% [markdown]
# ## Objetivo
# Comparar baselines y modelos ML. NO usar test set. NO seleccionar ganador definitivo.

# %%
# TODO: implementar

# %% [markdown]
# ## Inputs
# - data/processed/train.csv, validation.csv
# - manifests/02_data_preparation.json

# %%
# TODO: implementar

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from pathlib import Path

# %% [markdown]
# ## 1. Carga de datos

# %%
# TODO: implementar

# %% [markdown]
# ## 2. Baselines (lag-1, lag-7, MA-7)

# %%
# TODO: implementar

# %% [markdown]
# ## 3. Modelo lineal (ElasticNet)

# %%
# TODO: implementar

# %% [markdown]
# ## 4. GradientBoosting (central + cuantil 95)

# %%
# TODO: implementar

# %% [markdown]
# ## 5. Comparación en validation (MAE, RMSE, WAPE)

# %%
# TODO: implementar

# %% [markdown]
# ## 6. Leaderboard

# %%
# TODO: implementar

# %% [markdown]
# ## 7. Persistencia de modelos

# %%
# TODO: implementar

# %% [markdown]
# ## 8. Conclusiones
#
# **Estado:** GO / REVISAR / NO-GO
#
# **Siguiente:** evaluation-business

# %%
# TODO: implementar
