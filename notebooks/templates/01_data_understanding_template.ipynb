# %% [markdown]
# # 01 — Entendimiento de Datos

# %% [markdown]
# ## Objetivo
# Determinar si los datos son aptos para modelar retiros diarios y soportar la decisión de liquidez.

# %%
# TODO: implementar

# %% [markdown]
# ## Inputs
# - data/raw/daily_withdrawals.csv
# - docs/product-brief.md
# - manifests/00_business_understanding.json

# %%
# TODO: implementar

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from pathlib import Path

# %% [markdown]
# ## 1. Carga y esquema

# %%
# TODO: implementar

# %% [markdown]
# ## 2. Calidad (nulos, duplicados, valores imposibles)

# %%
# TODO: implementar

# %% [markdown]
# ## 3. Comportamiento temporal (tendencia, estacionalidad semanal, quincena, festivos)

# %%
# TODO: implementar

# %% [markdown]
# ## 4. Distribución del target

# %%
# TODO: implementar

# %% [markdown]
# ## 5. Outliers contextualizados

# %%
# TODO: implementar

# %% [markdown]
# ## 6. Viabilidad predictiva (variables disponibles en D, riesgos leakage)

# %%
# TODO: implementar

# %% [markdown]
# ## 7. Conclusiones y decisión
#
# **Estado:** GO / REVISAR / NO-GO
#
# **Hallazgos:**
#
# **Riesgos:**
#
# **Siguiente:** data-preparation

# %%
# TODO: implementar
