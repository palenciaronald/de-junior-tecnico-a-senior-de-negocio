# %% [markdown]
# # 04 — Evaluación Técnica y de Negocio
#
# ## Objetivo
# Evaluar sobre TEST (primera y única vez). Gráfico de inferencia. Traducir a KPIs de negocio. Seleccionar modelo y política.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import json, joblib
from pathlib import Path
from datetime import datetime
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# ## 1. Carga de modelos y test set

# %%
# TODO: cargar test.csv + modelos candidatos

# %% [markdown]
# ## 2. Gráfico de inferencia (real vs predicho en test)
#
# Serie temporal con real (línea sólida) vs predicciones (líneas punteadas) + banda cuantil 95.

# %%
# TODO: plotly con real vs pred_gbr vs pred_enet + banda Q95

# %% [markdown]
# ## 3. Scorecard técnico
#
# MAPE, SMAPE, MdAPE, MAE, RMSE, POE, PUE, MOE, MUE, Pinball, Cobertura

# %%
# TODO: tabla de métricas técnicas

# %% [markdown]
# ## 4. Función de costo de negocio
#
# C(q,y) = c_ociosidad * max(q-y,0) + c_faltante * max(y-q,0)

# %%
# TODO: implementar función de costo

# %% [markdown]
# ## 5. Backtest de políticas

# %%
# TODO: tradicional vs modelo Q95 vs modelo+buffer

# %% [markdown]
# ## 6. Gráfico de políticas (reserva vs real)

# %%
# TODO: serie temporal de reserva diaria vs retiro real

# %% [markdown]
# ## 7. Gráfico de dinero ocioso y faltante

# %%
# TODO: barras apiladas ocioso/faltante por política

# %% [markdown]
# ## 8. Selección del ganador

# %%
# TODO: seleccionar por costo total + servicio >= 95%

# %% [markdown]
# ## 9. Conclusiones
#
# **Estado:** GO / REVISAR / NO-GO
#
# **Modelo seleccionado:**
# **Política seleccionada:**
# **Razón:**
#
# **Siguiente:** productization-deployment

# %%
# TODO: generar manifest + selected_model.json
