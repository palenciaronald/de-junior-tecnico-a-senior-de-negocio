# %% [markdown]
# # 04 — Evaluación Técnica y de Negocio

# %% [markdown]
# ## Objetivo
# Evaluar candidatos sobre TEST. Traducir métricas técnicas a KPIs de negocio. Seleccionar modelo y política.

# %%
# TODO: implementar

# %% [markdown]
# ## Inputs
# - data/processed/test.csv
# - artifacts/models/
# - outputs/model_leaderboard.csv
# - manifests/03_model_tournament.json

# %%
# TODO: implementar

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from pathlib import Path

# %% [markdown]
# ## 1. Carga de modelos candidatos y test set

# %%
# TODO: implementar

# %% [markdown]
# ## 2. Métricas técnicas (MAE, RMSE, WAPE, pinball, cobertura)

# %%
# TODO: implementar

# %% [markdown]
# ## 3. Función de costo: C(q,y) = c_ociosidad*max(q-y,0) + c_faltante*max(y-q,0)

# %%
# TODO: implementar

# %% [markdown]
# ## 4. Backtest de negocio (dinero ocioso, faltante, nivel servicio)

# %%
# TODO: implementar

# %% [markdown]
# ## 5. Comparación vs política tradicional

# %%
# TODO: implementar

# %% [markdown]
# ## 6. Selección del modelo ganador

# %%
# TODO: implementar

# %% [markdown]
# ## 7. Conclusiones
#
# **Estado:** GO / REVISAR / NO-GO
#
# **Modelo seleccionado:**
# **Razón:**
#
# **Siguiente:** productization-deployment

# %%
# TODO: implementar
