# %% [markdown]
# # 02 — Preparación de Datos

# %% [markdown]
# ## Objetivo
# Construir datasets supervisados reproducibles para forecasting temporal.

# %%
# TODO: implementar

# %% [markdown]
# ## Inputs
# - data/raw/daily_withdrawals.csv
# - manifests/01_data_understanding.json

# %%
# TODO: implementar

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from pathlib import Path

# %% [markdown]
# ## 1. Carga y ordenamiento cronológico

# %%
# TODO: implementar

# %% [markdown]
# ## 2. Features de calendario

# %%
# TODO: implementar

# %% [markdown]
# ## 3. Lags y ventanas móviles (con shift correcto)

# %%
# TODO: implementar

# %% [markdown]
# ## 4. Validación de leakage

# %%
# TODO: implementar

# %% [markdown]
# ## 5. Separación temporal (train/validation/test)

# %%
# TODO: implementar

# %% [markdown]
# ## 6. Documentación de features

# %%
# TODO: implementar

# %% [markdown]
# ## 7. Exportación de datasets
#
# **Estado:** GO / REVISAR / NO-GO
#
# **Siguiente:** modeling-tournament

# %%
# TODO: implementar
